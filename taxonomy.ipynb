# %% [markdown]
# # Towards Automated Taxnonomy Construction
# ### This notebook contains the code that generated the graphs in the Illumination Works, LLC "Towards Automated Taxonomy Construction" Blog
#
# Brian Connolly, Sr. Consultant at Illumination Works, LLC

# %% [markdown]
# ## install relevant libraries

# %%
# !pip install moz_sql_parser
# !pip install pyspark
# !pip install pyarrow
# !pip install anytree
# !pip install subprocess
# !pip install pydot
# !pip install python-graphviz
# !pip install copy
# Out:
# Requirement already satisfied: moz_sql_parser in c:\users\connollyb\anaconda3\lib\site-packages (4.40.21126)
# Requirement already satisfied: mo-logs==4.23.21108 in c:\users\connollyb\anaconda3\lib\site-packages (from moz_sql_parser) (4.23.21108)
# Requirement already satisfied: mo-dots==4.22.21108 in c:\users\connollyb\anaconda3\lib\site-packages (from moz_sql_parser) (4.22.21108)
# Requirement already satisfied: mo-future==3.147.20327 in c:\users\connollyb\anaconda3\lib\site-packages (from moz_sql_parser) (3.147.20327)
# Requirement already satisfied: mo-imports==3.149.20327 in c:\users\connollyb\anaconda3\lib\site-packages (from mo-dots==4.22.21108->moz_sql_parser) (3.149.20327)
# Requirement already satisfied: mo-kwargs==4.22.21108 in c:\users\connollyb\anaconda3\lib\site-packages (from mo-logs==4.23.21108->moz_sql_parser) (4.22.21108)
# Requirement already satisfied: pyspark in c:\users\connollyb\anaconda3\lib\site-packages (3.4.1)
# Requirement already satisfied: py4j==0.10.9.7 in c:\users\connollyb\anaconda3\lib\site-packages (from pyspark) (0.10.9.7)
# Requirement already satisfied: pyarrow in c:\users\connollyb\anaconda3\lib\site-packages (12.0.1)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\connollyb\anaconda3\lib\site-packages (from pyarrow) (1.23.5)
# Requirement already satisfied: anytree in c:\users\connollyb\anaconda3\lib\site-packages (2.9.0)
# Requirement already satisfied: six in c:\users\connollyb\anaconda3\lib\site-packages (from anytree) (1.16.0)
# ERROR: Could not find a version that satisfies the requirement subprocess (from versions: none)
# ERROR: No matching distribution found for subprocess
# Requirement already satisfied: pydot in c:\users\connollyb\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\connollyb\anaconda3\lib\site-packages (from pydot) (3.0.9)
# ERROR: Could not find a version that satisfies the requirement python-graphviz (from versions: none)
# ERROR: No matching distribution found for python-graphviz
# ERROR: Could not find a version that satisfies the requirement copy (from versions: none)
# ERROR: No matching distribution found for copy

# %% [markdown]
# ## Import libraries

# %%
from scipy import spatial
import re
from moz_sql_parser import parse
import pandas as pd
from scipy import stats
from pyspark.sql.functions import pandas_udf
from ast import literal_eval
import numpy as np
from anytree import Node, RenderTree
import glob
# https://stackoverflow.com/questions/49333295/rendering-a-tree-in-python-using-anytree-and-graphviz-without-merging-common-no
import anytree
from anytree import Node, RenderTree
from nltk.tokenize import sent_tokenize, word_tokenize
import warnings
warnings.filterwarnings(action = 'ignore')
import gensim
from gensim.models import Word2Vec
# https://stackoverflow.com/questions/56741217/using-anytree-to-convert-json-to-a-image
from anytree.exporter import DotExporter
from anytree.importer import JsonImporter
from anytree import RenderTree
from anytree import Node
from anytree.dotexport import RenderTreeGraph
# https://stackoverflow.com/questions/56741217/using-anytree-to-convert-json-to-a-image
import anytree.exporter as atex
import anytree as at
import json
import pydot
from anytree.dotexport import RenderTreeGraph
from anytree.exporter import DotExporter
import os
import ast
import copy

# %% [markdown]
# ## Define Functions

# %% [markdown]
# ### these are the core functions used to get the data ready for analysis
# Only the queries in the json data files are used for analysis here, and so it is only important the a record with the key word 'sql' be included in a format like in the following example:
#
# "sql": [
#             "SELECT JOURNALalias0.HOMEPAGE FROM JOURNAL AS JOURNALalias0 WHERE JOURNALalias0.NAME = \"journal_name0\" ;"
#         ]

# %%
def select_udf(x):
    """ 
    function used within pandas apply function to extract fields from (not all) select statements 
    within .json files in the text2sql data set
   
    Parameters
    ------------
        x: str
            json in parsed_sql column in pandas DataFrame build from text2sql .json file

    Return
    -----------
        selects: list
        returns list of select statements or it errors out and returns None
    """ 
    try:
        select = x.get('select')
        selects = []
        if type(select)==list:
            for value in select:
#                 print(value)
                if 'value' in value.keys():
                    val = value.get('value')
                    if type(val)==str:
                        selects += [val]
        elif type(select)==dict and type(select.get('value'))==str:
            selects = [select['value']]
        else:
            if type(select['value']['distinct'])==list:
#                 print(select['value']['distinct'])
                for value in select['value']['distinct']:
                    if 'value' in value.keys():
                        val = value.get('value')
                        if type(val)==str:
                            selects += [val]
            elif type(select['value']['distinct']['value'])==str:
                selects += [select['value']['distinct']['value']] 
        return selects
    except Exception as error:
#        print("select_udf: An exception occurred:", error)
        return None
    
def parse_udf(x):
    """ 
    function used within pandas apply function to parse sql statements 
    within json found within text2sql data set
   
    Parameters
    ------------
        x: str
            json in sql column in pandas DataFrame build from text2sql .json file

    Return
    -----------
        : dict
        sql statements parsed in a .json format
    """ 
    try:
        return parse(x)
    except:    
        return "parse_udf: failed: "+x
    
def groupby_udf(x):
    """ 
    function used within pandas apply function to extract fields from (not all) group by statements 
    within .json files in the text2sql data set
   
    Parameters
    ------------
        x: str
            json in parsed_sql column in pandas DataFrame build from text2sql .json file

    Return
    -----------
        selects: list
        returns list of group by statements or it errors out and returns None
    """ 
    try:
        groupby = x.get('groupby')
        if type(groupby) is list:
            if len(groupby)==0:
                return None
            else:
                groupby = [y['value'] for y in groupby]
#                 print(groupby)
        else:
            groupby = [groupby['value']]
        return groupby
    except Exception as error:
#       print("groupby_udf: An exception occurred:", error)
        return None

def create_trees_2(groupbys,png_directory="graph_png_files"): 
    """ 
    - returns a list of Nodes for tree
    - generates png files of trees for those trees where the top nodes have one field in the graph_png_files sub-directory
   
    Parameters
    ------------
        groupbys: list 
            list of fields in select or groupby statements
        png_directory: str (Optional)
            sub-directory to which png will be written
    Return
    -----------
        nodes: list
            list of Node objects
    """ 

    if not os.path.exists(png_directory):
        os.makedirs(png_directory)
    
    nodes = []
    parent_nodes = []
    for groupby in groupbys: # re-initialize
        parent_nodes += [Node(groupby)]
    for parent_node in parent_nodes:
        if len(parent_node.name)<2:
            for groupby in groupbys: # re-initialize nodes
                nodes += [Node(groupby)]
            groupbys_zipped = [(len(x),x) for x in groupbys]
            nodes = find_children(nodes,groupbys_zipped,parent_node,parent_level=1,max_levels=10)
            ordered_node_list = [(x,len(x.name)) for x in nodes]
            ordered_node_list.sort(key = lambda y: y[1],reverse=True)
            for node,length in ordered_node_list:
                if node.parent is not None:
                    node.name = ','.join(list(set(node.name)-set(node.parent.name)))
            parent_node.name = ','.join(parent_node.name)
    #       print(RenderTree(parent_node))
            base_name = parent_node.name.replace(',','__').replace("*","[WILDCARD]")
            if base_name=="":
                base_name = '_'
            atex.DotExporter(
                parent_node, nodeattrfunc = lambda n : 'label="{}"'.format(n.name),edgeattrfunc = lambda node, child: "dir=none"
            ).to_picture(png_directory+"\\"+base_name+".png")
#       print("")
    return nodes

# %% [markdown]
# ## Helper functions

# %%
def flatten(l):
    """ 
    flattens a list of lists
   
    Parameters
    ------------
        l: list
            list of lists
    Return
    -----------
         : list
            flattened list
    """    
    return [item for sublist in l for item in sublist]

def find_children(nodes,groupbys_zipped,parent_node,parent_level,max_levels):
    """ 
    recursive function that finds the children of parent_node given a list of nodes 
   
    Parameters
    ------------
        nodes: list of Node objects
            current list of nodes over entire tree from which children of parent_node is determined
        groupbys_zipped: list of tuples containing (number of fields in select statement,fields in select or groupby statement)
        parent_node: Node 
            parent node for which you want to find children
        parent_level: int
            level of parent tree over entire tree (top level is parent_level=0)
        max_levels: int
            maximum number of levels that you want to consider for tree
    Return
    -----------
        nodes : list of Node object
            list of child nodes
    """ 
    
    if parent_level>max_levels:
        return nodes
    parent_group = parent_node.name
    groupbys = [x[1] for x in groupbys_zipped]
    for groupby in [x[1] for x in groupbys_zipped]:
        if set(parent_group)<set(groupby):
            child_level = parent_level+1
            children = [x[1] for x in groupbys_zipped if (x[0]==child_level) and (set(parent_group)<set(x[1]))]
            for child in children:
                child_node = find_node_by_name(nodes,child)[1]
                child_node.parent=parent_node
                nodes = find_children(nodes,groupbys_zipped,child_node,child_level,max_levels)
    return nodes
                

def find_node_by_name(list_of_nodes,node_name):
    """ 
    given a list of nodes, return the Node object with the name node_name
   
    Parameters
    ------------
        list_of_nodes: list of Node objects
            list of Node objects - one of which contains a Node with name node_name
        node_name: str
            node name of Node you want to find
    Return
    -----------
        nodes: list
            list of Node objects
    """ 
    
    for inode,node in enumerate(list_of_nodes):
        if node.name==node_name:
            return inode,node
    return None,None

def unique_list_of_lists(my_list):
    """ 
    generic function that, given a list of lists (my_list), returns a unique list of lists
   
    Parameters
    ------------
        my_list: list of lists

    Return
    -----------
        : list
        returns either a unique list, or if it is unable to return the list of some reason, it errors out and returns None
    """ 
    
    try:
        return [list(x) for x in set(tuple(x) for x in my_list)]
    except Exception as error: # handle the exception
        print("unique_list_of_lists: An exception occurred:", error)
        return None

# %% [markdown]
# ### Run a couple of tests to get some intuition

# %%
# [SOME EXPLANATION OF OUTPUT]
groupbys_test1 = [['State'],['State','Governor'],['State','Size']]  
create_trees_2(groupbys_test1,'examples')
#
groupbys_test1 = [['a','b'],['a'],['a','b','c'],['b','c']]  
create_trees_2(groupbys_test1,'examples')
#
groupbys_test2 = [['a','b'],['b'],['a','b','c'],['c'],['a','b','c','d']]    
create_trees_2(groupbys_test2,'examples')
#
selects_test=[["city"],["city","address"],["city","address","square footage"],["city","population"]]
create_trees_2(selects_test,'examples')
# Out:
# [Node("/['city']"),
#  Node('/city/address'),
#  Node('/city/address/square footage'),
#  Node('/city/population')]

# %% [markdown]
# ## Now ingest the data that is used to create tables in blog, and extract the fields from some of the select statements

# %%
# create list of .json files in data set
json_files = [file for file in glob.glob("data\\text2sql-data\\data\\*") if file[-5:]=='.json']
# json_files = json_files[:2] # UNCOMMENT THIS FOR TESTING

# %%
# put all the .json files into a single pandas DataFrame
json_df=pd.DataFrame()
for json_file in json_files:
    json_df = pd.concat([json_df,pd.read_json(json_file)])
json_df = json_df.explode('sql')

# %%
# extract the select and group by statements
json_df["parsed_sql"] = json_df["sql"].apply(lambda x: parse_udf(x))
json_df['select'] = json_df['parsed_sql'].apply(lambda x: select_udf(x))
json_df['groupby'] = json_df['parsed_sql'].apply(lambda x: groupby_udf(x))

# %% [markdown]
# ## put unique select statements into a list

# %%
selects = unique_list_of_lists(json_df[~json_df['select'].isnull()]['select'])

# %% [markdown]
# ## create the anytree and put images of trees with various parents in specified png_directory through the create_trees_2 function

# %%
create_trees_2(selects,png_directory="graph_png_files")
# Out:
# [Node('/INSTITUTIONalias0.INSTITUTION/A,,,C,L'),
#  Node('/FESTIVAL_DETAILalias0.LOCATION/M'),
#  Node('/COURSEalias0.TITLE/A,,,M,N'),
#  Node('/ARTISTalias0.COUNTRY/,,E,M'),
#  Node("/['DETENTIONalias0.DETENTION_SUMMARY']"),
#  Node('/ACCOUNTSalias0.NAME/I,,,D'),
#  Node("/['BEDTYPE']"),
#  Node("/['AIRLINESalias0.COUNTRY']"),
#  Node('/DRIVERSalias0.FORENAME/U'),
#  Node("/['FLIGHTalias0.AIRLINE_CODE']"),
#  Node("/['PAYMENTSalias0.PAYMENT_DATE']"),
#  Node("/['PRODUCTSalias0.MANUFACTURER']"),
#  Node("/['F_ID', 'SONGalias0.ARTIST_NAME', 'SONGalias0.GENRE_IS']"),
#  Node("/['DOCUMENT_TYPESalias0.DOCUMENT_TYPE_CODE']"),
#  Node('/RACESalias0.NAME/,,D,T'),
#  Node("/['GAS_STATIONalias0.LOCATION']"),
#  Node("/['CITEalias0.CITINGPAPERID']"),
#  Node("/['DERIVED_TABLEalias0.FRIEND']"),
#  Node("/['PROFESSIONALSalias0.EMAIL_ADDRESS']"),
#  Node("/['CAMERA_LENSalias0.NAME']"),
#  Node("/['THIRD_PARTY_COMPANIESalias0.COMPANY_ID']"),
#  Node("/['DOCUMENT_TYPE_DESCRIPTION']"),
#  Node("/['GAS_STATIONalias0.LOCATION', 'GAS_STATIONalias0.MANAGER_NAME', 'GAS_STATIONalias0.STATION_ID']"),
#  Node("/['STAFFalias0.NAME']"),
#  Node("/['TREATMENTSalias0.COST_OF_TREATMENT']"),
#  Node('/PRODUCTSalias0.PRODUCT_CATEGORY_CODE/L,I,,,N,B'),
#  Node("/['TRIPalias0.BIKE_ID']"),
#  Node("/['COURSE_AUTHORS_AND_TUTORSalias0.ADDRESS_LINE_1']"),
#  Node("/['MISSIONalias0.FATE']"),
#  Node("/['SCIENTISTSalias0.NAME']"),
#  Node("/['FAREalias0.FARE_BASIS_CODE']"),
#  Node('/EMPLOYEEalias0.EMP_FNAME/I,S,,,R,C/N,D,U,T'),
#  Node("/['SWIMMERalias0.NATIONALITY']"),
#  Node("/['PHONEalias0.NAME']"),
#  Node("/['INVOICESalias0.ORDER_ID']"),
#  Node("/['PEOPLEalias0.HEIGHT']"),
#  Node('/VENUEalias0.VENUEID/A,R,,,P'),
#  Node("/['DOCUMENTS_WITH_EXPENSESalias0.BUDGET_TYPE_CODE']"),
#  Node("/['FILM_MARKET_ESTIMATIONalias0.YEAR']"),
#  Node("/['HOSTING_CITYalias0.HOST_CITY']"),
#  Node("/['DOCUMENT_TYPE_CODE']"),
#  Node("/['UNIVERSITYalias0.FOUNDED']"),
#  Node("/['COURSEalias0.DEPARTMENT', 'COURSEalias0.NAME', 'COURSEalias0.NUMBER', 'SEMESTERalias0.SEMESTER', 'SEMESTERalias0.YEAR', 'STUDENT_RECORDalias0.GRADE']"),
#  Node("/['PLAYERSalias0.HAND']"),
#  Node("/['PRODUCT_SUPPLIERSalias0.SUPPLIER_ID']"),
#  Node("/['MEMBERalias0.LEVEL']"),
#  Node("/['REPRESENTATIVEalias0.NAME']"),
#  Node("/['UNDERGOESalias0.PATIENT']"),
#  Node('/SECTIONSalias0.SECTION_NAME/R,,,D,P'),
#  Node("/['PROJECTSalias0.PROJECT_DETAILS']"),
#  Node('/PILOTalias0.PILOT_NAME/C,,,R,F,D'),
#  Node('//0,E,S,.,N,D,T,_,L,I,a,O,P,l,A,,,G,s,R,i,C,M'),
#  Node("/['DRAMA_WORKSHOP_GROUPSalias0.STORE_NAME']"),
#  Node("/['AIRLINEalias0.AIRLINE_CODE']"),
#  Node('//0,S,.,N,D,T,_,Y,H,L,I,a,O,l,A,,,U,s,R,i,C'),
#  Node('//0,E,S,.,D,_,Y,L,I,a,O,P,l,A,,,s,R,i,M'),
#  Node('//0,E,S,.,N,B,F,D,T,_,H,L,I,K,a,O,P,l,A,,,U,s,R,i,C,M'),
#  Node("/['ASSETSalias0.ASSET_ACQUIRED_DATE']"),
#  Node("/['MILLalias0.TYPE']"),
#  Node("/['ADDRESSESalias0.COUNTRY']"),
#  Node("/['UNIT_OF_MEASURE']"),
#  Node('//0,E,S,.,N,B,F,D,T,_,I,K,a,O,l,A,,,U,G,s,R,i,M'),
#  Node("/['LISTalias0.LASTNAME']"),
#  Node("/['AIRLINESalias0.AIRLINE']"),
#  Node("/['JOURNALalias0.THEME']"),
#  Node("/['FAULT_LOGalias0.FAULT_LOG_ENTRY_ID']"),
#  Node('/COUNTRYalias0.NAME/P,I,,,L/H,S,O,E,A,F,D,T'),
#  Node("/['HOSTalias0.NAME']"),
#  Node('//0,E,.,B,D,T,L,I,K,a,l,A,,,U,s,R,i,C,M'),
#  Node("/['STUDENTalias0.TOTAL_CREDIT']"),
#  Node('//0,V,E,S,.,N,T,_,Y,H,L,I,a,O,l,A,,,U,s,R,i,C'),
#  Node("/['PERFORMANCEalias0.STAGEPOSITION']"),
#  Node("/['AIRCRAFTalias0.FLEET_SERIES']"),
#  Node('/PARAGRAPHSalias0.PARAGRAPH_TEXT/I,,,D'),
#  Node('//0,E,S,.,N,D,_,Y,L,I,a,O,P,l,A,,,G,s,R,i,M'),
#  Node("/['NEIGHBORHOODalias0.NAME']"),
#  Node('/ARTISTalias0.GENDER/_,,,M'),
#  Node('/ADDRESSESalias0.LINE_1/2'),
#  Node("/['RESTYPEDESCRIPTION']"),
#  Node("/['COMPETITIONalias0.COMPETITION_TYPE']"),
#  Node("/['BUSINESSalias0.REVIEW_COUNT']"),
#  Node("/['APT_TYPE_CODE']"),
#  Node('//0,E,S,.,N,F,T,_,Y,a,O,P,l,A,,,U,s,R,i,M'),
#  Node('/DEBATEalias0.VENUE/'),
#  Node('/EMPLOYEEalias0.EMP_FNAME/B,,,D'),
#  Node('/GAMEalias0.DATE/_,Y,L,I,J,P,,,N,U,R,C'),
#  Node("/['ROOMNAME']"),
#  Node("/['PLAYERalias0.PNAME']"),
#  Node('/KEYPHRASEalias0.KEYPHRASENAME/'),
#  Node("/['ASSETSalias0.ASSET_MODEL']"),
#  Node('/STAFFalias0.NAME/_,L,H,I,O,,,R,D'),
#  Node('/INSTITUTIONalias0.INSTITUTION/_,E,P,A,,,R,M'),
#  Node('//0,E,S,.,N,F,D,T,_,L,I,a,O,l,A,,,U,s,R,i,C,M/'),
#  Node('//0,E,S,.,N,D,T,_,H,I,a,O,P,l,A,,,G,s,R,i,C,M'),
#  Node('/CUSTOMERSalias0.CUSTOMER_ID/A,,,L'),
#  Node('/DOCUMENTSalias0.DOCUMENT_NAME/I,,,L'),
#  Node('/EMPLOYEESalias0.JOB_ID/H,A,,,R,T'),
#  Node("/['CAPTAINalias0.RANK']"),
#  Node('//0,V,E,S,.,N,B,D,T,_,Y,L,I,K,a,O,P,l,A,,,U,G,s,R,i,C'),
#  Node("/['DEPT_NAME']"),
#  Node("/['HOTELSalias0.OTHER_HOTEL_DETAILS']"),
#  Node('/DEPARTMENTalias0.NAME/_,Y,L,S,O,,,U'),
#  Node('/SAVINGSalias0.BALANCE/O,,,U,M,T'),
#  Node("/['BRANCHalias0.CITY']"),
#  Node('/CLASSROOMalias0.BUILDING/_,,,E'),
#  Node("/['STUDENTSalias0.FIRST_NAME']"),
#  Node("/['ARTWORKalias0.NAME']"),
#  Node('//0,_,L,I,a,E,.,l,,,i,s,F,D,M,T/S,O,P,N,R,C'),
#  Node('/PLAYERSalias0.FIRST_NAME/B,,,D,H'),
#  Node('/AIRCRAFTalias0.NAME/D'),
#  Node('/PROJECT_STAFFalias0.DATE_TO/M'),
#  Node("/['APARTMENT_BUILDINGSalias0.BUILDING_ADDRESS']"),
#  Node("/['MATCHESalias0.WINNER_NAME']"),
#  Node('/MOUNTAINalias0.NAME/D'),
#  Node('/PRODUCTSalias0.PRODUCT_NAME/Y,L,I,,,G,B'),
#  Node("/['STADIUMalias0.COUNTRY']"),
#  Node('/PAPERalias0.PAPERID/H,O,,,U,T'),
#  Node("/['USER_PROFILESalias0.EMAIL']"),
#  Node('/CONDUCTORalias0.NAME/,,S,H'),
#  Node("/['BRANCHalias0.NAME']"),
#  Node("/['VENUEID']"),
#  Node("/['SCREEN_MODEalias0.CHAR_CELLS', 'SCREEN_MODEalias0.HARDWARE_COLOURS', 'SCREEN_MODEalias0.PIXELS']"),
#  Node("/['CAR_NAMESalias0.MODEL']"),
#  Node("/['STATIONalias0.NAME']"),
#  Node('/WEB_CLIENT_ACCELERATORalias0.OPERATING_SYSTEM/'),
#  Node("/['CLAIMSalias0.DATE_CLAIM_MADE']"),
#  Node("/['EDITORalias0.NAME']"),
#  Node("/['FLIGHTalias0.STOPS']"),
#  Node("/['COMPETITIONalias0.COUNTRY']"),
#  Node("/['DEGREESalias0.CAMPUS']"),
#  Node('/TEACHERSalias0.FIRST_NAME/,,D,O'),
#  Node("/['ALL_DOCUMENTSalias0.DATE_STORED']"),
#  Node("/['CNAME']"),
#  Node("/['MATCHalias0.MATCH_ID']"),
#  Node("/['PROPERTIESalias0.PROPERTY_ID']"),
#  Node('/STAFFalias0.LAST_NAME/R,,,I/D,L'),
#  Node("/['BUILDINGalias0.FLOORS', 'BUILDINGalias0.NAME', 'BUILDINGalias0.STREET_ADDRESS']"),
#  Node('//0,E,S,.,N,F,D,T,L,I,a,l,A,,,U,s,R,i,M'),
#  Node('/CHECKINGalias0.BALANCE/S,O,,,U,M,T/L,V,I,G,B'),
#  Node("/['WRITESalias0.PAPERID']"),
#  Node("/['PEOPLEalias0.BIRTH_PLACE']"),
#  Node('/DOCUMENTSalias0.RECEIPT_DATE/'),
#  Node('/ENZYMEalias0.NAME/L,I,O,,,C,T/0,Y,a,E,Z,.,l,P,N,U,s,R,i,D,M'),
#  Node('/PRODUCTSalias0.PRODUCT_NAME/Y'),
#  Node("/['PARKalias0.STATE']"),
#  Node("/['PRODUCTSalias0.PRODUCT_ID']"),
#  Node("/['STATEalias0.CAPITAL']"),
#  Node('/COURSEalias0.NUMBER/A'),
#  Node("/['COUNTRYLANGUAGEalias0.COUNTRYCODE']"),
#  Node("/['FILESalias0.FORMATS']"),
#  Node('/DORMalias0.DORM_NAME/G'),
#  Node('//0,E,.,N,F,T,_,L,I,a,l,A,,,s,R,i,M'),
#  Node("/['DRAFT_COPIESalias0.DOCUMENT_ID']"),
#  Node('/RAILWAYalias0.LOCATION/,,E,M'),
#  Node("/['STAFFalias0.DATE_LEFT_STAFF']"),
#  Node('/EVENTSalias0.EVENT_DETAILS/R,,,C'),
#  Node("/['FILMalias0.DIRECTED_BY']"),
#  Node("/['PROGRAMalias0.NAME', 'PROGRAMalias0.ORIGIN', 'PROGRAMalias0.OWNER']"),
#  Node("/['DERIVED_TABLEalias0.TRANSACTION_TYPE_DESCRIPTION']"),
#  Node('/AUTHORSalias0.LNAME/F'),
#  Node('//0,E,S,.,N,D,T,_,Y,L,I,a,O,P,l,A,,,U,s,R,i,C,M'),
#  Node('/DERIVED_TABLEalias0.NAME/G'),
#  Node("/['DOGSalias0.SIZE_CODE', 'OWNERSalias0.FIRST_NAME', 'OWNERSalias0.LAST_NAME']"),
#  Node("/['MATCH_SEASONalias0.COLLEGE']"),
#  Node("/['ADDRESSalias0.ADDRESS']"),
#  Node('/ARCHITECTalias0.NAME/D'),
#  Node("/['DOCUMENTSalias0.RESPONSE_RECEIVED_DATE']"),
#  Node('/CUST_NAME/B,,,L'),
#  Node('/PLAYERalias0.PLAYER_NAME/,,D,G'),
#  Node("/['COURSEalias0.TITLE']"),
#  Node("/['CHANNELalias0.NAME']"),
#  Node("/['PAPERKEYPHRASEalias0.PAPERID']"),
#  Node('/BODY_BUILDERalias0.CLEAN_JERK/,,S,H,T'),
#  Node("/['WRITERalias0.BIRTH_CITY']"),
#  Node('/ELECTIONalias0.DELEGATE/R,,,Y,P'),
#  Node('/PARTIESalias0.PAYMENT_METHOD_CODE/'),
#  Node('/DERIVED_TABLEalias0.SERVICE_TYPE_DESCRIPTION/'),
#  Node("/['FAULT_LOGalias0.FAULT_DESCRIPTION', 'FAULT_LOGalias0.FAULT_LOG_ENTRY_DATETIME', 'FAULT_LOGalias0.FAULT_LOG_ENTRY_ID']"),
#  Node('/ELECTIONalias0.DELEGATE/M'),
#  Node('/STATIONalias0.NAME/,,C,L/_,E,P,U,B,R,F,M'),
#  Node('/EMPLOYEEalias0.NAME/I,,,D'),
#  Node("/['AREA_CODE_STATEalias0.AREA_CODE']"),
#  Node("/['FAREalias0.FARE_AIRLINE', 'FAREalias0.FARE_BASIS_CODE', 'FAREalias0.FARE_ID', 'FAREalias0.FROM_AIRPORT', 'FAREalias0.ONE_DIRECTION_COST', 'FAREalias0.RESTRICTION_CODE', 'FAREalias0.ROUND_TRIP_COST', 'FAREalias0.ROUND_TRIP_REQUIRED', 'FAREalias0.TO_AIRPORT']"),
#  Node("/['FARM_COMPETITIONalias0.THEME']"),
#  Node('/MOVIEalias0.DIRECTOR/L/S,A,,,N,G,R'),
#  Node('/VOTING_RECORDalias0.ELECTION_CYCLE/A,,,S'),
#  Node('/ACCOUNTSalias0.STATEMENT_ID/L/0,E,S,.,N,D,T,_,I,a,O,A,l,,,U,s,i,C'),
#  Node("/['BUILDINGSalias0.STORIES']"),
#  Node("/['AIRPORTSalias0.AIRPORTCODE']"),
#  Node('/PLAYERalias0.PLAYER_NAME/,,C,O,H'),
#  Node("/['VOTING_RECORDalias0.ELECTION_CYCLE']"),
#  Node("/['COUNTRYLANGUAGEalias0.LANGUAGE']"),
#  Node("/['FOOD_SERVICEalias0.MEAL_DESCRIPTION']"),
#  Node("/['PUBLICATIONalias0.PUBLICATION_DATE']"),
#  Node("/['REVIEWERalias0.NAME']"),
#  Node('/ENZYMEalias0.NAME/L,I,O,,,C,T'),
#  Node("/['MOVIEalias0.TITLE', 'RATINGalias0.STARS', 'REVIEWERalias0.NAME']"),
#  Node('//0,E,S,.,N,D,R,_,I,a,A,l,,,s,K,i,C,M'),
#  Node('/DEPARTMENTSalias0.DEPARTMENT_NAME/Y,L,I,O,,,F'),
#  Node('/ROLESalias0.ROLE_DESCRIPTION/A,,,M/C,D'),
#  Node("/['DRIVERalias0.PARTY']"),
#  Node('/TRANSACTIONSalias0.DATE_OF_TRANSACTION/U,,,H'),
#  Node('/ORDERSalias0.ORDER_ID/A,,,L,T'),
#  Node("/['ASSESSMENT_NOTESalias0.DATE_OF_NOTES']"),
#  Node("/['MAILSHOT_CUSTOMERSalias0.OUTCOME_CODE']"),
#  Node("/['PLAYLISTSalias0.NAME']"),
#  Node('/PAPERalias0.PAPERID/_,Y,H,L,V,S,,,B,K,T'),
#  Node('/DOCUMENTSalias0.DOCUMENT_NAME/I/R,,,P'),
#  Node("/['STUDENTSalias0.LOGIN_NAME']"),
#  Node("/['TOURIST_ATTRACTIONSalias0.HOW_TO_GET_THERE']"),
#  Node("/['CUSTOMERalias0.CUST_NAME']"),
#  Node("/['BANKalias0.BNAME']"),
#  Node('/AIRCRAFTalias0.FLEET_SERIES/P,O,,,N,M'),
#  Node("/['STUDENTSalias0.CELL_MOBILE_NUMBER']"),
#  Node('//0,E,S,.,N,F,T,_,Y,L,I,a,O,P,l,A,,,s,R,i,M/D/0,E,S,.,B,_,Y,L,I,J,a,O,P,l,,,s,i,M'),
#  Node("/['USERalias0.USER_ID']"),
#  Node('/PAPERalias0.PAPERID/Y,H,S,,,K'),
#  Node("/['INVESTORSalias0.INVESTOR_DETAILS']"),
#  Node('//0,E,S,.,N,B,F,D,_,L,I,a,O,P,l,A,,,U,s,R,i,C,M'),
#  Node("/['CUSTOMERalias0.ADDRESS']"),
#  Node("/['DERIVED_TABLEalias0.DOCUMENT_TYPE_NAME']"),
#  Node("/['CITEalias0.CITEDPAPERID']"),
#  Node("/['VENUEalias0.VENUEID']"),
#  Node('/ITEMalias0.TITLE/_,,,D'),
#  Node("/['EMPLOYEESalias0.ROLE_CODE']"),
#  Node("/['ROLLER_COASTERalias0.NAME']"),
#  Node("/['TRACKSalias0.NAME']"),
#  Node("/['CATALOGSalias0.CATALOG_PUBLISHER']"),
#  Node("/['EMP_FNAME']"),
#  Node("/['EMPLOYEESalias0.JOB_ID']"),
#  Node("/['PUBLICATIONalias0.TITLE']"),
#  Node("/['BANDalias0.LASTNAME']"),
#  Node('/DERIVED_TABLEalias0.NAME/G/0,V,E,.,B,D,T,_,L,I,a,A,l,,,s,R,i'),
#  Node("/['AIRLINE']"),
#  Node("/['FACULTYalias0.SEX']"),
#  Node('/BASKETBALL_MATCHalias0.TEAM_NAME/O,,,U,G,R'),
#  Node("/['GRAPESalias0.GRAPE']"),
#  Node("/['STUDENT_COURSE_REGISTRATIONSalias0.STUDENT_ID']"),
#  Node('/STUDENTSalias0.FIRST_NAME/L/I'),
#  Node("/['COURSESalias0.COURSE_DESCRIPTION']"),
#  Node("/['STORMalias0.NAME']"),
#  Node("/['PREMISESalias0.PREMISES_TYPE']"),
#  Node("/['APARTMENTSalias0.BATHROOM_COUNT', 'APARTMENTSalias0.BEDROOM_COUNT', 'APT_TYPE_CODE']"),
#  Node("/['DERIVED_TABLEalias0.PRODUCT_CATEGORY_DESCRIPTION']"),
#  Node('/SUBMISSIONalias0.AUTHOR/L,E,P,,,C'),
#  Node("/['RACEalias0.CLASS']"),
#  Node('/EVENTalias0.NAME/U/0,V,a,E,.,l,A,,,N,s,i,D,T'),
#  Node("/['PROBLEMSalias0.PROBLEM_ID']"),
#  Node('/SCIENTISTSalias0.NAME/J,P,O,,,R/U,H'),
#  Node("/['MATCHESalias0.TOURNEY_NAME']"),
#  Node('//0,E,S,.,N,F,D,T,_,L,a,l,A,,,U,s,i,M'),
#  Node('/STU_FNAME/,,P,G/N,O,E,H'),
#  Node('/CINEMAalias0.NAME/,,O,L,T'),
#  Node('/JOBSalias0.JOB_TITLE/Y,P,,,D,M'),
#  Node("/['FESTIVAL_DETAILalias0.LOCATION']"),
#  Node('//0,E,S,.,N,B,F,D,T,_,L,I,a,O,P,l,A,,,U,G,s,i,C,M'),
#  Node('/TRAINalias0.NAME/V,,,C,S'),
#  Node("/['CLASSalias0.CLASS_CODE']"),
#  Node('//0,E,.,T,_,Y,L,a,P,A,l,,,G,s,R,i'),
#  Node("/['CLIMBERalias0.TIME']"),
#  Node("/['CONSTRUCTORSalias0.NATIONALITY']"),
#  Node('/EMPLOYEESalias0.DEPARTMENT_ID/F'),
#  Node("/['PEOPLEalias0.CELL_MOBILE_NUMBER']"),
#  Node("/['STUDENT_COURSE_ENROLMENTalias0.DATE_OF_ENROLMENT']"),
#  Node("/['CLIMBERalias0.NAME']"),
#  Node("/['TRANSACTIONSalias0.DATE_OF_TRANSACTION']"),
#  Node("/['PHYSICIANalias0.NAME']"),
#  Node("/['DEPARTMENTalias0.DEPT_NAME']"),
#  Node('/ADDRESSESalias0.CITY/_,U,N,,'),
#  Node("/['BUILDINGalias0.NAME']"),
#  Node("/['DEATHalias0.NOTE']"),
#  Node('/STUDENTalias0.LNAME/F/_,L,V,I,O,P,,,G,B,R'),
#  Node("/['AIRPORTSalias0.NAME']"),
#  Node('/SINGERalias0.NAME/,,O,L,T'),
#  Node('/VENUEalias0.VENUENAME/I,P,,,R,D'),
#  Node("/['BOOK_CLUBalias0.BOOK_TITLE', 'BOOK_CLUBalias0.PUBLISHER', 'BOOK_CLUBalias0.YEAR']"),
#  Node('//E,S,.,N,F,T,_,Y,L,I,a,O,P,1,l,A,,,s,R,i,M'),
#  Node('/EVENTalias0.NAME/U'),
#  Node("/['AIRCRAFTalias0.BASIC_TYPE']"),
#  Node("/['GYMNASTalias0.TOTAL_POINTS']"),
#  Node('//0,V,E,S,.,N,B,T,_,Y,H,L,I,K,a,O,l,A,,,U,G,s,R,i,C,M'),
#  Node("/['DRIVERSalias0.FORENAME']"),
#  Node("/['REF_SHIPPING_AGENTS.SHIPPING_AGENT_NAME']"),
#  Node("/['CUSTOMERSalias0.CUSTOMER_STATUS_CODE']"),
#  Node('/STATIONalias0.NAME/,,C,L'),
#  Node("/['TEAMalias0.NAME']"),
#  Node("/['FIRSTNAME']"),
#  Node("/['SCHOOLalias0.ENROLLMENT']"),
#  Node("/['HOTELSalias0.STAR_RATING_CODE']"),
#  Node("/['GRANTSalias0.ORGANISATION_ID']"),
#  Node("/['ORDERSalias0.ORDER_ID']"),
#  Node("/['CHECKINGalias0.BALANCE']"),
#  Node('/ADDRESSESalias0.ZIP_POSTCODE/U,,,N'),
#  Node('/PETSalias0.WEIGHT/D'),
#  Node('/MATCHESalias0.WINNER_NAME/K'),
#  Node('//0,E,S,.,N,B,F,D,T,_,Y,H,L,I,K,a,O,P,l,A,,,s,R,i,M'),
#  Node("/['COURSEalias0.ADVISORY_REQUIREMENT']"),
#  Node('/TEACHERSalias0.FIRST_NAME/L'),
#  Node("/['CAPTAINalias0.CLASS', 'CAPTAINalias0.NAME', 'CAPTAINalias0.RANK']"),
#  Node("/['MANUFACTURERSalias0.FOUNDER']"),
#  Node('/EMPLOYEEalias0.NAME/R,,,S'),
#  Node("/['DAYSalias0.DAY_NAME']"),
#  Node("/['PARTYalias0.LOCATION']"),
#  Node("/['HAS_ALLERGYalias0.ALLERGY']"),
#  Node("/['CARS_DATAalias0.YEAR']"),
#  Node('//0,E,S,.,N,D,T,_,L,I,a,l,A,,,s,i,C,M'),
#  Node("/['TEACHERSalias0.LASTNAME']"),
#  Node('/DERIVED_TABLEalias0.KEYPHRASEID/'),
#  Node("/['ROLLER_COASTERalias0.STATUS']"),
#  Node("/['AUTHORalias1.NAME']"),
#  Node("/['DOCUMENTSalias0.GRANT_ID']"),
#  Node('/AIRLINESalias0.COUNTRY/M'),
#  Node("/['AUTHORalias0.HOMEPAGE']"),
#  Node("/['ENTREPRENEURalias0.COMPANY']"),
#  Node("/['CITYalias0.STATUS']"),
#  Node("/['RAILWAYalias0.OBJECTNUMBER']"),
#  Node('/CUSTOMERSalias0.CUSTOMER_ID/A,,,L/V,N'),
#  Node("/['PROJECT_STAFFalias0.PROJECT_ID']"),
#  Node("/['TV_CHANNELalias0.PACKAGE_OPTION']"),
#  Node("/['CONDUCTORalias0.NAME']"),
#  Node('/RAILWAYalias0.LOCATION/_,,,D'),
#  Node("/['DOCUMENTS_TO_BE_DESTROYEDalias0.DESTROYED_BY_EMPLOYEE_ID']"),
#  Node('/TECHNICIANalias0.NAME/_,R,,,S'),
#  Node("/['CHECKINalias0.DAY']"),
#  Node('/DOCUMENT_TYPE_DESCRIPTION/A/'),
#  Node("/['AIRPORTSalias0.CITY', 'AIRPORTSalias0.NAME', 'ROUTESalias0.SRC_APID']"),
#  Node("/['ADDRESSESalias0.ZIP_POSTCODE']"),
#  Node("/['EDITORalias0.AGE']"),
#  Node("/['SALARYalias0.SALARY']"),
#  Node("/['ARTISTalias0.COUNTRY']"),
#  Node('//0,E,S,.,N,_,H,L,I,a,O,P,l,A,,,U,s,R,i,M'),
#  Node("/['COURSE_OFFERINGalias0.END_TIME', 'COURSE_OFFERINGalias0.SECTION_NUMBER', 'COURSE_OFFERINGalias0.START_TIME']"),
#  Node("/['PLAYERalias0.POSITION']"),
#  Node("/['PROGRAMalias0.ORIGIN']"),
#  Node('/SECTIONalias0.YEAR/M'),
#  Node('//0,E,S,.,N,B,T,_,a,O,l,A,,,U,s,R,i,C,M'),
#  Node('//0,S,E,.,F,T,_,Y,L,I,a,P,A,l,,,s,R,i'),
#  Node("/['DRIVERalias0.NAME']"),
#  Node("/['FURNITUREalias0.NAME']"),
#  Node("/['GROUND_SERVICEalias0.TRANSPORT_TYPE']"),
#  Node('/PAPERalias0.VENUEID/Y'),
#  Node('/DOCUMENTSalias0.DOCUMENT_NAME/'),
#  Node("/['PEOPLEalias0.*']"),
#  Node('//S,E,.,N,B,a,O,1,l,A,,,U,s,R,i,C,M/D,P,T'),
#  Node("/['PERFORMANCEalias0.HOST']"),
#  Node('/SONGalias0.SONG_NAME/L,,,R,D,T'),
#  Node('/STADIUMalias0.NAME/,,O,G'),
#  Node('//0,E,.,B,D,_,L,I,a,O,P,l,,,G,s,R,i,M'),
#  Node("/['ENDOWMENTalias0.DONATOR_NAME']"),
#  Node('//0,V,E,.,F,D,T,_,H,L,I,a,P,l,A,,,U,G,s,R,i'),
#  Node("/['PRODUCT_CATEGORY_DESCRIPTION']"),
#  Node('/ROOMNAME/I,,,D'),
#  Node('/LISTalias0.LASTNAME/R,,,F'),
#  Node("/['PHONEalias0.COMPANY_NAME']"),
#  Node('/TV_CHANNELalias0.COUNTRY/I,S,P,,,X'),
#  Node("/['BANDalias0.FIRSTNAME']"),
#  Node("/['DEPARTMENTalias0.CREATION']"),
#  Node("/['EMPLOYEESalias0.PHONE']"),
#  Node('//0,E,S,.,N,F,T,_,L,I,a,O,l,A,,,U,s,R,i,C,M/P,H'),
#  Node("/['DEPARTMENTSalias0.DEPARTMENT_DESCRIPTION']"),
#  Node("/['FACID']"),
#  Node("/['CINEMAalias0.NAME', 'FILMalias0.TITLE', 'SCHEDULEalias0.DATE', 'SCHEDULEalias0.PRICE']"),
#  Node("/['TRAINalias0.ORIGIN']"),
#  Node("/['FLIGHTalias0.DATE', 'FLIGHTalias0.PILOT', 'FLIGHTalias0.VEHICLE_FLIGHT_NUMBER']"),
#  Node("/['EMPLOYEEalias0.SEX']"),
#  Node("/['HEADalias0.AGE']"),
#  Node("/['DRAMA_WORKSHOP_GROUPSalias0.STORE_EMAIL_ADDRESS']"),
#  Node("/['APPELLATIONSalias0.COUNTY']"),
#  Node('/MANUFACTURERSalias0.NAME/,,Q,H,D/0,F,a,S,E,.,A,l,N,O,U,s,R,i,C,M,T'),
#  Node("/['CATALOG_CONTENTSalias0.CATALOG_ENTRY_NAME']"),
#  Node("/['BLOCKalias0.BLOCKCODE']"),
#  Node('//0,E,S,.,N,F,D,T,_,I,a,O,l,A,,,U,s,R,i,C,M'),
#  Node("/['COUNTRYalias0.COUNTRY']"),
#  Node("/['GRAPESalias0.COLOR']"),
#  Node("/['EMPLOYEESalias0.DEPARTMENT_ID']"),
#  Node("/['USERalias0.NAME']"),
#  Node('/JOURNALISTalias0.NAME/V,,,D'),
#  Node("/['BUDGET_TYPE_DESCRIPTION']"),
#  Node("/['DERIVED_TABLEalias0.FRIEND', 'DERIVED_TABLEalias0.NAME', 'PERSONalias0.AGE']"),
#  Node('//0,E,S,.,B,D,T,_,H,L,I,a,O,l,A,,,U,G,s,R,i,C,M'),
#  Node("/['PRODUCTS_FOR_HIREalias0.PRODUCT_NAME']"),
#  Node("/['DOCUMENTSalias0.DOCUMENT_NAME']"),
#  Node("/['ACTUAL_ORDERSalias0.ACTUAL_ORDER_ID']"),
#  Node('/MATCHESalias0.WINNER_NAME/P,K,,,O'),
#  Node('/COMPANYalias0.COMPANY/R,,,K'),
#  Node("/['SCHOOLalias0.IHSAA_FOOTBALL_CLASS', 'SCHOOLalias0.MASCOT', 'SCHOOLalias0.SCHOOL_NAME']"),
#  Node('/STUDENTalias0.FNAME/X'),
#  Node('/INSTRUCTORalias0.NAME/_,,,D,H'),
#  Node("/['FORMSalias0.FORM_NAME']"),
#  Node("/['SHIPalias0.TYPE']"),
#  Node("/['DOCUMENT_STATUS_DESCRIPTION']"),
#  Node("/['CUSTOMERSalias0.CUSTOMER_NAME']"),
#  Node("/['TV_CHANNELalias0.ID']"),
#  Node("/['PRODUCTalias0.MAX_PAGE_SIZE']"),
#  Node('/COURSE_AUTHORS_AND_TUTORSalias0.ADDRESS_LINE_1/'),
#  Node('/COUNTRYalias0.COUNTRY_NAME/P,I,,,L'),
#  Node("/['PROGRAM_COURSEalias0.WORKLOAD']"),
#  Node('//0,V,E,.,N,F,D,T,_,Y,L,I,a,O,l,,,s,R,i,M'),
#  Node("/['POKER_PLAYERalias0.MONEY_RANK']"),
#  Node('/STUDENTalias0.MAJOR/G'),
#  Node("/['RIVERalias0.LENGTH']"),
#  Node('/OWNERSalias0.LAST_NAME/I,,,D'),
#  Node("/['WRITERalias0.NATIONALITY']"),
#  Node("/['ORGANISATION_TYPESalias0.ORGANISATION_TYPE_DESCRIPTION']"),
#  Node("/['CAR_MAKERSalias0.MAKER']"),
#  Node('/ELIMINATIONalias0.TEAM/R,,,S,W'),
#  Node('//0,V,E,S,.,N,B,D,T,_,Y,L,I,a,O,P,l,A,,,U,s,R,i,C,M/'),
#  Node('//0,E,S,.,N,D,T,_,Y,L,I,a,O,P,l,A,,,U,s,R,i,C,M'),
#  Node('/DOCUMENTSalias0.DOCUMENT_NAME/H,I,P,,,G,R'),
#  Node("/['APARTMENT_BUILDINGSalias0.BUILDING_DESCRIPTION']"),
#  Node("/['HOTELSalias0.PETS_ALLOWED_YN']"),
#  Node('/STUDENTSalias0.FIRST_NAME/'),
#  Node('/STUDENT_COURSE_ENROLMENTalias0.DATE_OF_ENROLMENT/I,,,P'),
#  Node("/['PRODUCTSalias0.PRODUCT_PRICE']"),
#  Node("/['SONGalias0.LANGUAGES']"),
#  Node('/CLASS_OF_SERVICEalias0.BOOKING_CLASS/D'),
#  Node("/['POSTSEASONalias0.YEAR']"),
#  Node('/ROOMNAME/0,a,S,.,D,l,,,s,i,C'),
#  Node("/['I_ID']"),
#  Node('//0,E,S,.,N,F,T,_,Y,L,I,a,P,l,A,,,s,R,i,M/D,W,G'),
#  Node("/['MOVIEalias0.DIRECTOR']"),
#  Node('/EMPLOYEEalias0.EMP_FNAME/I,S,,,R,C/N,D,U,T/0,_,E,P,a,.,A,l,s,R,i,M'),
#  Node("/['COUNTRYalias0.COUNTRY_NAME', 'MATCH_SEASONalias0.PLAYER', 'MATCH_SEASONalias0.SEASON']"),
#  Node("/['ELECTIONalias0.DELEGATE']"),
#  Node('/LNAME/F/0,Y,L,H,a,P,.,O,l,,,U,s,i,C,T'),
#  Node('/USER_PROFILESalias0.NAME/W'),
#  Node("/['DEPARTMENTalias0.NAME']"),
#  Node("/['STU_FNAME']"),
#  Node('//0,V,E,S,.,N,B,D,T,_,H,L,I,a,O,l,A,,,U,s,R,i,C,M'),
#  Node("/['PRODUCERalias0.NATIONALITY']"),
#  Node("/['WINEalias0.GRAPE']"),
#  Node("/['DEPARTMENTalias0.HEAD']"),
#  Node('/CITYalias0.GDP/'),
#  Node("/['SONGSalias0.TITLE']"),
#  Node('/DEPT_NAME/0,s,a,.,l,,,U,G,B,R,i'),
#  Node("/['FLIGHTalias0.ARRIVAL_TIME']"),
#  Node("/['PAPERSalias0.TITLE']"),
#  Node("/['COMPANYalias0.NAME']"),
#  Node("/['USERACCTalias0.NAME']"),
#  Node("/['SHIPPING_AGENT_CODE']"),
#  Node("/['LAKEalias0.LAKE_NAME']"),
#  Node("/['STATEalias0.DENSITY']"),
#  Node('/BATTLEalias0.NAME/R,,,S,U'),
#  Node('/PARTYalias0.PARTY_NAME/I,,,O,G'),
#  Node('/MEMBERalias0.NAME/_,L,I,O,,,G,C,T'),
#  Node('//0,E,S,.,N,T,_,Y,I,J,a,O,l,A,,,s,R,i,M'),
#  Node('//S,E,.,N,B,a,O,1,l,A,,,U,s,R,i,C,M'),
#  Node("/['BATTLEalias0.NAME']"),
#  Node("/['PARKalias0.CITY']"),
#  Node("/['LOCATION_CODE']"),
#  Node('/TRIPalias0.START_STATION_NAME/D'),
#  Node('/STORMalias0.NAME/_,P,,,X,D'),
#  Node("/['CATEGORYalias0.NAME']"),
#  Node("/['CITYalias0.DISTRICT']"),
#  Node("/['SHOPalias0.NAME']"),
#  Node("/['CLASSalias0.CLASS_ROOM']"),
#  Node("/['FLIGHTSalias0.FLIGHTNO']"),
#  Node("/['SHIPalias0.BUILT_YEAR']"),
#  Node('/CAMERA_LENSalias0.NAME/B,,,D'),
#  Node("/['ORCHESTRAalias0.ORCHESTRA']"),
#  Node('/PLAYERalias0.OCCUPATION/,,D,G'),
#  Node('//0,E,S,.,N,B,D,T,L,I,a,l,A,,,U,s,R,i,M'),
#  Node('/UNIVERSITYalias0.SCHOOL/A,K,,,M'),
#  Node("/['TEACHERSalias0.GENDER']"),
#  Node("/['PAPERalias0.VENUEID']"),
#  Node("/['INVOICESalias0.PAYMENT_METHOD_CODE']"),
#  Node('/STAFFalias0.STAFF_NAME/I,,,D'),
#  Node('/MOVIEalias0.TITLE/,,U,G,B,D'),
#  Node('/EMPLOYEEalias0.EMP_FNAME/H,I,S,,,G,R,D'),
#  Node("/['MUSICALalias0.NAME']"),
#  Node("/['WRITERalias0.BIRTH_YEAR']"),
#  Node('/APARTMENTSalias0.APT_NUMBER/Y,O,D,,,C'),
#  Node("/['MOUNTAINalias0.STATE_NAME']"),
#  Node("/['MANAGERalias0.WORKING_YEAR_STARTS']"),
#  Node("/['BODY_BUILDERalias0.TOTAL']"),
#  Node("/['PROGRAM_COURSEalias0.CATEGORY']"),
#  Node('/SHIPalias0.NAME/D'),
#  Node('/PRODUCTSalias0.PRODUCT_PRICE/A,,,M,N/Y'),
#  Node("/['VENUEalias0.VENUENAME']"),
#  Node("/['GAMEalias0.AWAY_TEAM', 'GAMEalias0.HOME_TEAM', 'GAMEalias0.SEASON']"),
#  Node("/['AIRPORT_SERVICEalias0.MILES_DISTANT']"),
#  Node("/['TV_CHANNELalias0.CONTENT']"),
#  Node('/ACCOUNTSalias0.STATEMENT_ID/L'),
#  Node("/['INSTRUMENTSalias0.INSTRUMENT']"),
#  Node('/DRAMA_WORKSHOP_GROUPSalias0.STORE_EMAIL_ADDRESS/N'),
#  Node("/['STUDENTSalias0.OTHER_STUDENT_DETAILS']"),
#  Node("/['CARS_DATAalias0.CYLINDERS']"),
#  Node('/BEDTYPE/O,A,,,N,R,M'),
#  Node('/BUILDINGalias0.NAME/_,H,,,F,T'),
#  Node("/['TV_CHANNELalias0.COUNTRY']"),
#  Node('/PRODUCTSalias0.PRODUCT_CATEGORY_CODE/,,M,N'),
#  Node("/['HEADalias0.NAME']"),
#  Node("/['CAPTAINalias0.NAME']"),
#  Node("/['CANDIDATEalias0.POLL_SOURCE']"),
#  Node("/['ORDER_ITEMSalias0.PRODUCT_ID']"),
#  Node("/['DNAME']"),
#  Node("/['PAPERalias0.JOURNALID']"),
#  Node("/['ACCOUNTSalias0.OTHER_ACCOUNT_DETAILS']"),
#  Node('/MANUFACTURERSalias0.NAME/,,Q,H,D/0,F,V,a,S,E,.,A,l,N,U,s,R,i,C,M,T'),
#  Node("/['EMPLOYEESalias0.PHONE_NUMBER']"),
#  Node('/HEADalias0.NAME/_,I,,'),
#  Node('//0,E,.,B,D,T,_,H,L,I,K,a,O,l,A,,,U,s,R,i,C'),
#  Node("/['SHOPalias0.LOCATION']"),
#  Node("/['PLAYERalias0.NAME']"),
#  Node('/CITYalias0.GDP/_,L,E,O,A,,,N,U,R'),
#  Node("/['EVENTalias0.NAME']"),
#  Node('/STATIONalias0.NAME/L'),
#  Node("/['COURSEalias0.DEPT_CODE']"),
#  Node("/['ENZYMEalias0.NAME']"),
#  Node("/['INVOICESalias0.PRODUCT_ID']"),
#  Node('/BROWSERalias0.NAME/I,,,D/_,H,A,K,M,T'),
#  Node('/MEMBERalias0.NAME/_,H,I,O,D,,,U,C,T'),
#  Node("/['INDIVIDUALSalias0.INDIVIDUAL_LAST_NAME']"),
#  Node("/['CLUBNAME']"),
#  Node("/['COURSEalias0.NUMBER']"),
#  Node("/['STATEalias0.POPULATION']"),
#  Node("/['COURSE_OFFERINGalias0.HAS_FINAL_EXAM']"),
#  Node("/['PARTIESalias0.PARTY_EMAIL']"),
#  Node("/['PRODUCTSalias0.NAME']"),
#  Node("/['MANAGERalias0.COUNTRY']"),
#  Node("/['SINGERalias0.CITIZENSHIP']"),
#  Node('/PILOTalias0.POSITION/A,,,E,M'),
#  Node("/['CONFERENCEalias0.NAME']"),
#  Node('/ARTISTalias0.FAMOUS_TITLE/G'),
#  Node("/['STUDENT_COURSE_ENROLMENTalias0.DATE_OF_COMPLETION']"),
#  Node("/['RAILWAYalias0.LOCATION']"),
#  Node("/['DORMalias0.DORM_NAME']"),
#  Node('/DOGSalias0.NAME/_,,,R,F,T'),
#  Node("/['PLAYERalias0.RESIDENCE']"),
#  Node('/STATIONalias0.NAME/,,L,G'),
#  Node("/['PAPERalias0.PAPERID']"),
#  Node('/JOURNALalias0.THEME/I,,,D/0,a,E,O,.,l,A,G,s,R,i,T'),
#  Node('//0,E,S,.,D,Y,L,I,a,P,O,l,A,,,s,R,i,M'),
#  Node("/['PUBLICATIONalias0.ABSTRACT']"),
#  Node('/GTYPE/A,,,M,N'),
#  Node("/['DERIVED_TABLEalias0.PROPERTY_TYPE_DESCRIPTION']"),
#  Node("/['TEMPLATE_TYPE_CODE']"),
#  Node("/['STAFF_ROLESalias0.ROLE_DESCRIPTION']"),
#  Node('/ACCOUNTSalias0.CUSTOMER_ID/F'),
#  Node("/['STUDENTalias0.LNAME']"),
#  Node('/FLIGHTalias0.DEPARTURE_TIME/B,,,N'),
#  Node("/['TRACKalias0.NAME']"),
#  Node("/['DERIVED_TABLEalias2.NAME']"),
#  Node("/['ARCHITECTalias0.NAME']"),
#  Node('/PRODUCTSalias0.NAME/F'),
#  Node("/['GROUND_SERVICEalias0.GROUND_FARE']"),
#  Node('/DEGREE_PROGRAMSalias0.DEGREE_SUMMARY_NAME/I'),
#  Node("/['STADIUMalias0.AVERAGE_ATTENDANCE']"),
#  Node("/['AUTHORalias0.NAME']"),
#  Node("/['PRODUCTalias0.PRODUCT']"),
#  Node("/['STUDENTalias0.FNAME']"),
#  Node('/STAFFalias0.LAST_NAME/R,,,I'),
#  Node('/DRIVERSalias0.DRIVERID/Y,L,O,A,,,N,T'),
#  Node('/WRITESalias0.PAPERID/Y'),
#  Node("/['INVOICESalias0.INVOICE_NUMBER']"),
#  Node('//0,V,E,S,.,N,B,D,T,_,Y,L,I,a,O,P,l,A,,,U,s,R,i,C,M'),
#  Node("/['PROFESSIONALSalias0.CITY', 'PROFESSIONALSalias0.ROLE_CODE', 'PROFESSIONALSalias0.STATE', 'PROFESSIONALSalias0.STREET']"),
#  Node("/['ALLERGYTYPE']"),
#  Node("/['RESIDENTSalias0.OTHER_DETAILS']"),
#  Node("/['GENRESalias0.NAME']"),
#  Node('/HOTELSalias0.OTHER_HOTEL_DETAILS/,,C,N,G'),
#  Node("/['PRODUCTalias0.PRODUCT_ID']"),
#  Node("/['AIRPORTalias0.AIRPORT_CODE', 'AIRPORTalias0.AIRPORT_LOCATION', 'AIRPORTalias0.AIRPORT_NAME', 'AIRPORTalias0.COUNTRY_NAME', 'AIRPORTalias0.MINIMUM_CONNECT_TIME', 'AIRPORTalias0.STATE_CODE', 'AIRPORTalias0.TIME_ZONE_CODE']"),
#  Node('/CUSTOMERalias0.CUST_NAME/,,Y,P'),
#  Node('/FAULT_LOG_PARTSalias0.FAULT_STATUS/I,E,D,,,N,C'),
#  Node("/['APARTMENT_FACILITIESalias0.FACILITY_CODE']"),
#  Node("/['AUTHORSalias0.LNAME']"),
#  Node('/FILESalias0.FORMATS/_,,,Z'),
#  Node("/['COUNTY_PUBLIC_SAFETYalias0.NAME']"),
#  Node("/['ROOMSalias0.DECOR']"),
#  Node('/VOTING_RECORDalias0.PRESIDENT_VOTE/'),
#  Node("/['LIKESalias0.STUDENT_ID']"),
#  Node('//0,E,S,.,N,D,T,_,H,L,I,a,O,l,A,,,s,R,i,C,M'),
#  Node("/['PROCEDURESalias0.NAME']"),
#  Node('/CARS_DATAalias0.YEAR/K,,,M,N'),
#  Node("/['PAPERDATASETalias0.PAPERID']"),
#  Node("/['INSTRUCTORalias0.SALARY']"),
#  Node("/['FESTIVAL_DETAILalias0.YEAR']"),
#  Node('/HOTELSalias0.STAR_RATING_CODE/'),
#  Node("/['CONFERENCEalias0.HOMEPAGE']"),
#  Node("/['STAFFalias0.DATE_OF_BIRTH']"),
#  Node('/SUBJECTSalias0.SUBJECT_NAME/I,O,,,R,D'),
#  Node("/['TEMPERATUREalias0.JAN']"),
#  Node("/['PAYMENTSalias0.AMOUNT_PAYMENT', 'PAYMENTSalias0.DATE_PAYMENT_MADE', 'PAYMENTSalias0.PAYMENT_METHOD_CODE']"),
#  Node('/DORMalias0.GENDER/_,Y,I,S,P,A,,,U,C,T'),
#  Node("/['PROGRAM_REQUIREMENTalias0.ADDITIONAL_REQ', 'PROGRAM_REQUIREMENTalias0.CATEGORY', 'PROGRAM_REQUIREMENTalias0.MIN_CREDIT', 'PROGRAMalias0.NAME']"),
#  Node("/['FACULTYalias0.BUILDING']"),
#  Node('/APPELLATIONSalias0.COUNTY/R'),
#  Node("/['SUBMISSIONalias0.COLLEGE']"),
#  Node('/MATCHESalias0.WINNER_NAME/,,O,L'),
#  Node("/['FLIGHTalias0.TIME_ELAPSED']"),
#  Node("/['ID']"),
#  Node("/['PRODUCERalias0.BIRTH_CITY']"),
#  Node("/['APARTMENT_BOOKINGSalias0.BOOKING_STATUS_CODE']"),
#  Node("/['STAFFalias0.LAST_NAME']"),
#  Node("/['MATCH_SEASONalias0.PLAYER']"),
#  Node("/['ASSESSMENT_NOTESalias0.TEXT_OF_NOTES']"),
#  Node('/LNAME/F'),
#  Node("/['VISITSalias0.VISIT_DATE']"),
#  Node("/['STUDENT_TESTS_TAKENalias0.TEST_RESULT']"),
#  Node('/ROLESalias0.ROLE_DESCRIPTION/A,,,M'),
#  Node("/['TRANSACTIONS_LOTSalias0.LOT_ID']"),
#  Node('/PAPERalias0.JOURNALID/Y'),
#  Node('/EMPLOYEESalias0.DEPARTMENT_ID/F/0,S,E,.,N,T,_,Y,L,a,O,P,l,A,,,s,i,M'),
#  Node("/['CUSTOMER_ORDERSalias0.ORDER_DATE']"),
#  Node("/['ROLESalias0.ROLE_DESCRIPTION']"),
#  Node('//0,W,E,Z,S,.,N,D,_,I,a,O,P,l,,,s,R,i,C'),
#  Node('/CUSTOMERSalias0.CUSTOMER_ID/A,,,F,N'),
#  Node("/['WRITESalias1.AUTHORID']"),
#  Node('/TRACKalias0.NAME/I,,,S,G/O,L'),
#  Node("/['MILLalias0.NAME']"),
#  Node("/['ARTISTalias0.GENDER']"),
#  Node('/SHOPalias0.ADDRESS/_,I,,'),
#  Node('/DOGSalias0.NAME/_,W,I,,,R,F,T'),
#  Node("/['FARMalias0.TOTAL_HORSES']"),
#  Node("/['COUNTRIESalias0.COUNTRYNAME']"),
#  Node("/['CITYalias0.NAME']"),
#  Node("/['MOUNTAINalias0.NAME']"),
#  Node("/['WINEalias0.GRAPE', 'WINEalias0.WINERY', 'WINEalias0.YEAR']"),
#  Node('/COURSEalias0.NUMBER/A/,,D,P,T/_,Y,G'),
#  Node("/['APARTMENTSalias0.APT_NUMBER']"),
#  Node('/MEMBERalias0.NAME/Y,O,,,U,C,T'),
#  Node('//0,E,.,N,B,D,T,_,Y,L,I,a,O,P,l,A,,,G,s,R,i,M'),
#  Node('/DOCUMENTSalias0.DOCUMENT_NAME/'),
#  Node("/['CUSTOMERS_CARDSalias0.CARD_TYPE_CODE']"),
#  Node('//0,E,S,.,N,B,D,T,_,I,K,a,O,P,l,A,,,G,s,R,i,M'),
#  Node('/SINGERalias0.NAME/Y,O,,,U,C,T'),
#  Node("/['PARTYalias0.PARTY_NAME']"),
#  Node("/['ARTISTalias0.FAMOUS_TITLE']"),
#  Node("/['DOCUMENTSalias0.DOCUMENT_DESCRIPTION', 'DOCUMENTSalias0.DOCUMENT_NAME', 'DOCUMENTSalias0.DOCUMENT_TYPE_CODE']"),
#  Node("/['CANDIDATEalias0.CONSIDER_RATE', 'CANDIDATEalias0.OPPOSE_RATE', 'CANDIDATEalias0.SUPPORT_RATE']"),
#  Node("/['ROOMSalias0.ROOMNAME']"),
#  Node("/['VOLUMEalias0.ISSUE_DATE']"),
#  Node("/['SECTIONSalias0.SECTION_NAME']"),
#  Node("/['PROJECT_STAFFalias0.ROLE_CODE']"),
#  Node('/COUNTRYalias0.NAME/P,I,,,L/F,Y,E,A,N,X,C,T'),
#  Node("/['PAYMENTSalias0.CUSTOMER_ID']"),
#  Node('/DETENTIONalias0.DETENTION_TYPE_CODE/L,V,S,A,,,B,R'),
#  Node("/['AUTHORalias0.AUTHORNAME']"),
#  Node("/['STORMalias0.DATES_ACTIVE', 'STORMalias0.NAME', 'STORMalias0.NUMBER_DEATHS']"),
#  Node('/ELECTIONalias0.DELEGATE/_,Y,,,U,M'),
#  Node("/['DOGSalias0.AGE', 'DOGSalias0.NAME', 'DOGSalias0.WEIGHT']"),
#  Node('/BRANCHalias0.CITY/,,E,M/_,D,S,O'),
#  Node("/['LOCATIONSalias0.OTHER_DETAILS']"),
#  Node("/['TIPalias0.TEXT']"),
#  Node("/['DERIVED_TABLEalias1.KEYPHRASEID']"),
#  Node('/SUBMISSIONalias0.COLLEGE/H,A,,,R,T'),
#  Node("/['AIRCRAFTalias0.AIRCRAFT']"),
#  Node('//0,E,S,.,N,F,D,T,_,L,I,a,O,l,A,,,U,s,R,i,C,M'),
#  Node('//0,E,S,.,N,F,T,_,Y,L,I,a,P,l,A,,,s,R,i,M'),
#  Node("/['COURSEalias0.DEPARTMENT', 'COURSEalias0.DESCRIPTION', 'COURSEalias0.NUMBER']"),
#  Node("/['COURSE_OFFERINGalias0.SECTION_NUMBER']"),
#  Node("/['STUDENTalias0.MAJOR']"),
#  Node('/AIRCRAFTalias0.NAME/,,D,S'),
#  Node("/['GAMEalias0.DATE']"),
#  Node("/['STUDENTSalias0.FIRST_NAME', 'STUDENTSalias0.LAST_NAME', 'STUDENTSalias0.MIDDLE_NAME', 'STUDENTSalias0.STUDENT_ID', 'STUDENTSalias0.STUDENT_ID']"),
#  Node("/['TRANSACTIONSalias0.TRANSACTION_TYPE_CODE']"),
#  Node('/LOTSalias0.LOT_DETAILS/R,,,V,N'),
#  Node("/['WINEalias0.NAME']"),
#  Node("/['DRIVERSalias0.DRIVERID']"),
#  Node("/['MEDIA_TYPESalias0.NAME']"),
#  Node("/['WEB_CLIENT_ACCELERATORalias0.OPERATING_SYSTEM']"),
#  Node('/ORGANISATIONSalias0.ORGANISATION_DETAILS/'),
#  Node('/CMI_CROSS_REFERENCESalias0.SOURCE_SYSTEM_CODE/'),
#  Node('/PILOTalias0.NAME/G'),
#  Node('/STU_FNAME/,,P,G/N,E,L,M'),
#  Node("/['VISITS_RESTAURANTalias0.TIME']"),
#  Node("/['COUNTRYalias0.REGION']"),
#  Node('/BUILDINGSalias0.NAME/,,C,O,P'),
#  Node('/WRESTLERalias0.NAME/I,,,C,O'),
#  Node("/['STAFFalias0.FIRST_NAME']"),
#  Node('/PLAYERalias0.TEAM/H,I,S,O,,,N,C'),
#  Node("/['APT_NUMBER']"),
#  Node("/['CHARACTERISTICSalias0.CHARACTERISTIC_NAME']"),
#  Node('//0,E,S,.,N,B,D,T,_,I,K,a,O,P,l,A,,,G,s,R,i,M/U'),
#  Node("/['CUSTOMER_POLICIESalias0.POLICY_TYPE_CODE']"),
#  Node('/SERVICESalias0.SERVICE_TYPE_CODE/N'),
#  Node("/['ACC_TYPE', 'CUSTOMERalias0.CREDIT_SCORE', 'CUSTOMERalias0.STATE']"),
#  Node("/['PAYMENTSalias0.PAYMENT_METHOD_CODE']"),
#  Node('/TRIPalias0.START_STATION_NAME/D'),
#  Node("/['SUBJECTSalias0.SUBJECT_NAME']"),
#  Node("/['DERIVED_TABLEalias0.COUNTRY']"),
#  Node('/COUNTRYLANGUAGEalias0.COUNTRYCODE/'),
#  Node('/PERSONalias0.NAME/B,J,,'),
#  Node("/['COURSE_OFFERINGalias0.END_TIME', 'COURSE_OFFERINGalias0.START_TIME', 'SEMESTERalias0.SEMESTER', 'SEMESTERalias0.YEAR']"),
#  Node("/['INVOICEalias0.INVOICEDATE']"),
#  Node("/['PEOPLEalias0.PARTY']"),
#  Node("/['PEOPLEalias0.NATIONALITY']"),
#  Node("/['HEADalias0.AGE', 'HEADalias0.BORN_STATE', 'HEADalias0.NAME']"),
#  Node("/['PLAYERalias0.TEAM']"),
#  Node("/['CLASS_OF_SERVICEalias0.BOOKING_CLASS']"),
#  Node('/FLIGHTalias0.ARRIVAL_TIME/U,,,D,P'),
#  Node('/CLUBalias0.NAME/_,Y,I,P,,,R,D'),
#  Node('/COUNTY_PUBLIC_SAFETYalias0.NAME/'),
#  Node("/['CUSTOMERSalias0.CUSTOMER_LAST_NAME', 'CUSTOMERSalias0.PHONE_NUMBER', 'ORDERSalias0.CUSTOMER_ID']"),
#  Node("/['BLOCKCODE']"),
#  Node("/['PHONEalias0.HARDWARE_MODEL_NAME']"),
#  Node('/PROJECTSalias0.PROJECT_DETAILS/'),
#  Node("/['STUDENTSalias0.EMAIL_ADDRESS']"),
#  Node("/['MUSICALalias0.NOMINEE']"),
#  Node('//0,W,E,S,.,B,D,T,_,H,I,K,a,O,l,A,,,s,R,i,M'),
#  Node('/PHONEalias0.NAME/I,K,S,D,,,R,C,T'),
#  Node('/ELIMINATIONalias0.ELIMINATION_MOVE/R,,,S,W'),
#  Node("/['ACCELERATOR_COMPATIBLE_BROWSERalias0.COMPATIBLE_SINCE_YEAR']"),
#  Node("/['TECHNICIANalias0.NAME']"),
#  Node('/BANDalias0.LASTNAME/R,,,F,I'),
#  Node("/['PUBLICATIONalias0.YEAR']"),
#  Node("/['STADIUMalias0.NAME']"),
#  Node('//0,S,E,.,N,F,D,T,_,I,a,A,l,,,G,s,R,i'),
#  Node('/STUDENTSalias0.FIRST_NAME/O'),
#  Node('/COMPANYalias0.HEADQUARTERS/I'),
#  Node("/['CUSTOMERSalias0.GENDER']"),
#  Node("/['EVENTSalias0.EVENT_DETAILS']"),
#  Node("/['GAMEID']"),
#  Node('/DOCUMENTSalias0.DOCUMENT_NAME/P,I,,,L'),
#  Node('/TREATMENTSalias0.COST_OF_TREATMENT/Y,I,P,,,D'),
#  Node('/ALLERGYTYPE/'),
#  Node("/['HAPPY_HOURalias0.MONTH']"),
#  Node('//0,E,S,.,N,F,D,T,_,Y,L,I,a,O,P,l,A,,,U,s,R,i,M'),
#  Node('/ACTORalias0.FIRST_NAME/L/0,_,I,a,O,.,D,A,l,,,s,R,i,C,T'),
#  Node("/['TWEETSalias0.TEXT']"),
#  Node('/FURNITUREalias0.NAME/_,P,O,,,C'),
#  Node("/['SWIMMERalias0.NAME']"),
#  Node('//0,E,.,N,D,T,_,Y,H,L,I,a,O,P,l,A,,,s,R,i,M'),
#  Node('/MEMBERalias0.NAME/L,O,,,G,C'),
#  Node("/['CHECKINalias0.COUNT']"),
#  Node('/JOURNALISTalias0.NATIONALITY/,,E,G'),
#  Node("/['MOVIEalias0.TITLE']"),
#  Node("/['BOOKalias0.WRITER']"),
#  Node('/CITYalias0.CITY_CODE/H,L,V,S,P,A,,,G,R,F,M'),
#  Node('/ADDRESSESalias0.LINE_1/2/'),
#  Node('//0,E,.,N,F,D,_,L,I,a,O,l,A,,,U,G,s,i,C,M'),
#  Node("/['LOCATIONSalias0.LOCATION_NAME']"),
#  Node("/['FAULT_LOG_PARTSalias0.FAULT_STATUS']"),
#  Node('/WEATHERalias0.ZIP_CODE/'),
#  Node("/['REPRESENTATIVEalias0.STATE']"),
#  Node("/['MANUFACTURERSalias0.NAME']"),
#  Node("/['OWNERSalias0.LAST_NAME']"),
#  Node("/['TRIPalias0.ID']"),
#  Node("/['EMPLOYEESalias0.DATE_OF_BIRTH', 'EMPLOYEESalias0.EMPLOYEE_NAME', 'EMPLOYEESalias0.ROLE_CODE']"),
#  Node('/EVENTalias0.NAME/L,I,J,S,O,,,U,R'),
#  Node("/['FACULTYalias0.BUILDING', 'FACULTYalias0.PHONE', 'FACULTYalias0.ROOM']"),
#  Node("/['CARS_DATAalias0.MPG']"),
#  Node("/['CATALOG_ENTRY_NAME']"),
#  Node("/['MANAGERalias0.NAME']"),
#  Node('//0,E,S,.,N,T,L,a,O,l,A,,,G,s,R,i,C'),
#  Node('/CINEMAalias0.NAME/_,Y,P,O,,,G,R/0,I,a,E,.,A,l,N,s,i,C,M,T'),
#  Node("/['PARTIESalias0.PAYMENT_METHOD_CODE']"),
#  Node("/['PERFORMANCEalias0.ATTENDANCE']"),
#  Node("/['CUSTOMER_ORDERSalias0.CUSTOMER_ID']"),
#  Node("/['PLAYER_ATTRIBUTESalias0.PREFERRED_FOOT']"),
#  Node("/['ELIMINATIONalias0.ELIMINATION_MOVE']"),
#  Node("/['COUNTY_PUBLIC_SAFETYalias0.CRIME_RATE']"),
#  Node('//0,E,S,.,N,F,T,_,Y,L,I,a,O,P,l,A,,,s,R,i,M'),
#  Node("/['MANUFACTURERSalias0.HEADQUARTER']"),
#  Node('/PAPERID/0,L,a,.,l,,,s,i,T'),
#  Node("/['PHONEalias0.ACCREDITATION_TYPE']"),
#  Node("/['ADDRESSESalias0.CITY_TOWN']"),
#  Node("/['WINEalias0.PRICE']"),
#  Node("/['PEOPLEalias0.HOMETOWN']"),
#  Node('//0,E,.,N,D,T,_,Y,I,a,O,P,l,A,,,s,R,i,C,M'),
#  Node("/['INSTRUCTORalias0.NAME']"),
#  Node('/TRIPalias0.ID/O,A,,,N,U'),
#  Node("/['LANGUAGEalias0.NAME']"),
#  Node("/['CHANNELalias0.OWNER']"),
#  Node("/['CUST_NAME']"),
#  Node('//0,V,S,E,.,D,T,I,a,O,P,l,,,s,R,i'),
#  Node("/['UNIVERSITYalias0.AFFILIATION']"),
#  Node('/CITEalias0.CITEDPAPERID/H,O,,,N,U,M'),
#  Node('/PHONEalias0.CARRIER/_,Y,,,G,M'),
#  Node("/['FINANCIAL_TRANSACTIONSalias0.ACCOUNT_ID']"),
#  Node('/FLIGHTalias0.ORIGIN/S,E,A,,,D'),
#  Node('//0,W,V,E,S,.,N,T,_,I,K,a,O,l,A,,,s,R,i,C,M'),
#  Node("/['PERPETRATORalias0.LOCATION']"),
#  Node('/PUBLICATIONalias0.PUBLICATION_DATE/K'),
#  Node("/['PARTITIONID']"),
#  Node('/STUDENTSalias0.FIRST_NAME/L/I/0,_,S,E,a,.,l,,,N,U,s,i,D,T'),
#  Node('/ENZYMEalias0.NAME/I,,,D'),
#  Node('/UNIVERSITYalias0.PRIMARY_CONFERENCE/L'),
#  Node("/['PUBLICATIONalias0.REFERENCE_NUM']"),
#  Node("/['ORDERSalias0.DATE_ORDER_PLACED']"),
#  Node("/['INSTITUTIONalias0.TYPE']"),
#  Node("/['FACULTYalias0.ROOM']"),
#  Node('/LNAME/F/0,Y,L,K,a,.,l,,,U,s,R,i,C,T'),
#  Node('/SEMESTERSalias0.SEMESTER_NAME/I,,,D'),
#  Node('//0,E,S,.,N,F,D,T,_,L,a,l,A,,,U,s,i,M/I,P,O,R,C'),
#  Node("/['SHIPalias0.FLAG']"),
#  Node('/COUNTRYalias0.NAME/P,I,,,L'),
#  Node("/['HAS_ALLERGYalias0.STUID']"),
#  Node("/['SONGalias0.SONG_NAME']"),
#  Node("/['CITYalias0.CITY_CODE']"),
#  Node("/['MUSIC_FESTIVALalias0.DATE_OF_CEREMONY']"),
#  Node("/['DOGSalias0.NAME']"),
#  Node('/MEMBERalias0.NAME/_,I,,,D'),
#  Node("/['ADDRESSESalias0.ADDRESS_DETAILS']"),
#  Node('/CUSTOMERalias0.FIRST_NAME/L'),
#  Node("/['INDIVIDUALSalias0.INDIVIDUAL_FIRST_NAME', 'INDIVIDUALSalias0.INDIVIDUAL_LAST_NAME', 'INDIVIDUALSalias0.INDIVIDUAL_MIDDLE_NAME']"),
#  Node("/['PAPERKEYPHRASEalias0.KEYPHRASEID']"),
#  Node('//0,E,S,.,N,B,D,T,_,H,L,I,a,O,P,l,A,,,U,G,s,R,i,C,M'),
#  Node("/['DOMAINalias0.NAME']"),
#  Node("/['PETTYPE']"),
#  Node("/['VOTING_RECORDalias0.SECRETARY_VOTE']"),
#  Node("/['TEACHERSalias0.EMAIL_ADDRESS']"),
#  Node('//0,E,.,N,B,T,_,I,a,A,l,,,U,s,R,i,M'),
#  Node('/MOVIEalias0.TITLE/_,,,U,B,K,C'),
#  Node('/PLAYERSalias0.COUNTRY_CODE/I,,,F,M'),
#  Node("/['PILOTalias0.NAME']"),
#  Node("/['PPOS']"),
#  Node("/['ELIMINATIONalias0.TIME']"),
#  Node("/['WINEalias0.APPELATION']"),
#  Node("/['FLIGHTalias0.ORIGIN']"),
#  Node('/PEOPLEalias0.AGE/,,M,N'),
#  Node('/ARCHITECTalias0.NAME/,,O,Y,L'),
#  Node('/FINANCIAL_TRANSACTIONSalias0.ACCOUNT_ID/,,E,M'),
#  Node("/['PLAYERSalias0.COUNTRY_CODE']"),
#  Node('/FURNITUREalias0.NAME/_,K,,'),
#  Node('/COURSEalias0.NUMBER/A/,,D,P,T/'),
#  Node('/PERSONalias0.NAME/G'),
#  Node("/['PARAGRAPHSalias0.DOCUMENT_ID']"),
#  Node("/['JOURNALalias0.NAME']"),
#  Node("/['SCHOOLalias0.DENOMINATION']"),
#  Node("/['COUNTRYalias0.NAME']"),
#  Node("/['ROLLER_COASTERalias0.PARK']"),
#  Node('/ACTORalias0.FIRST_NAME/L'),
#  Node('/SHOPalias0.ADDRESS/_,,,N,U,F,M,T'),
#  Node("/['RESEARCH_OUTCOMESalias0.OUTCOME_DESCRIPTION']"),
#  Node('/HOSTalias0.NAME/_,Y,P,,,R'),
#  Node("/['SCHOOLalias0.MASCOT']"),
#  Node('/FACULTYalias0.LNAME//I,,,D'),
#  Node("/['FAREalias0.FARE_ID']"),
#  Node("/['PILOTalias0.JOIN_YEAR']"),
#  Node("/['CLUBLOCATION']"),
#  Node("/['BRIDGEalias0.NAME']"),
#  Node('//0,E,S,.,N,F,T,_,L,I,a,O,l,A,,,U,s,R,i,C,M'),
#  Node("/['COURSEalias0.NUM_ENROLLED']"),
#  Node("/['PRODUCERalias0.BIRTH_YEAR']"),
#  Node("/['MUSEUMalias0.NAME']"),
#  Node("/['FLNO']"),
#  Node("/['TRANSACTION_TYPE_DESCRIPTION']"),
#  Node("/['DERIVED_TABLEalias0.DATASETID']"),
#  Node('/STUDENTSalias0.FIRST_NAME/L'),
#  Node('/CATALOG_CONTENTSalias0.CATALOG_ENTRY_NAME/I,,,P'),
#  Node("/['MODEL_LISTalias0.MODEL']"),
#  Node("/['RESTAURANTalias0.RATING']"),
#  Node("/['LESSONSalias0.LESSON_ID']"),
#  Node('/TRACKalias0.NAME/I,,,O,L'),
#  Node("/['ORGANIZATIONalias0.HOMEPAGE']"),
#  Node("/['AIRPORTalias0.AIRPORT_CODE']"),
#  Node('/EDITORalias0.NAME/_'),
#  Node("/['PEOPLEalias0.AGE']"),
#  Node('/STAFFalias0.STAFF_NAME/R,,,D,G'),
#  Node("/['DETENTIONalias0.DETENTION_TYPE_CODE']"),
#  Node("/['MATCHalias0.VENUE']"),
#  Node("/['ASSETSalias0.ASSET_DETAILS', 'ASSETSalias0.ASSET_MAKE', 'ASSETSalias0.ASSET_MODEL']"),
#  Node("/['ADDRESSESalias0.CITY', 'CUSTOMERSalias0.CUSTOMER_NAME', 'CUSTOMER_ADDRESS_HISTORYalias0.DATE_FROM', 'CUSTOMER_ADDRESS_HISTORYalias0.DATE_TO']"),
#  Node("/['COURSEalias0.DEPARTMENT', 'COURSEalias0.NAME', 'COURSEalias0.NUMBER', 'PROGRAM_COURSEalias0.WORKLOAD', 'PROGRAM_COURSEalias0.WORKLOAD']"),
#  Node('/BRANCHalias0.NAME/_,Y,P,O,,'),
#  Node("/['CITYalias0.GDP']"),
#  Node("/['AIRPORTSalias0.CITY', 'AIRPORTSalias0.NAME', 'ROUTESalias0.DST_APID']"),
#  Node('//0,E,S,.,N,F,_,Y,L,I,a,O,P,l,A,,,s,R,i,C,M'),
#  Node("/['CUSTOMERSalias0.CUSTOMER_ID']"),
#  Node('/TV_SERIESalias0.EPISODE/A,,,N,G'),
#  Node("/['DATASETalias0.DATASETID']"),
#  Node('//0,E,S,.,N,B,F,D,T,_,H,L,I,a,O,P,l,,,U,G,s,R,i,M'),
#  Node("/['COURSE_OFFERINGalias0.END_TIME', 'COURSE_OFFERINGalias0.FRIDAY', 'COURSE_OFFERINGalias0.MONDAY', 'COURSE_OFFERINGalias0.SATURDAY', 'COURSE_OFFERINGalias0.START_TIME', 'COURSE_OFFERINGalias0.SUNDAY', 'COURSE_OFFERINGalias0.THURSDAY', 'COURSE_OFFERINGalias0.TUESDAY', 'COURSE_OFFERINGalias0.WEDNESDAY']"),
#  Node("/['ACC_TYPE']"),
#  Node("/['NEWS_REPORTalias0.WORK_TYPE']"),
#  Node('/LISTalias0.GRADE/,,v,r'),
#  Node("/['PUBLICATIONalias0.CITATION_NUM']"),
#  Node('/PLAYERSalias0.COUNTRY_CODE/I,,,F,M/0,_,Y,H,L,B,E,S,.,a,l,P,A,s,R,i,D,T'),
#  Node("/['TRUCKSalias0.TRUCK_DETAILS']"),
#  Node("/['DEPARTMENTSalias0.DEPARTMENT_NAME', 'LOCATIONSalias0.CITY', 'LOCATIONSalias0.STATE_PROVINCE']"),
#  Node("/['MEDICINE_ENZYME_INTERACTIONalias0.INTERACTION_TYPE']"),
#  Node("/['PROJECTSalias0.ORGANISATION_ID']"),
#  Node('/MANUFACTURERalias0.NAME/_,Y,P,O,,'),
#  Node("/['DEBATEalias0.VENUE']"),
#  Node("/['AIRLINESalias0.ABBREVIATION']"),
#  Node('/SINGERalias0.CITIZENSHIP/_,Y,A,,,B'),
#  Node("/['TRACKSalias0.MILLISECONDS']"),
#  Node('//0,V,E,S,.,D,T,_,I,a,O,P,l,A,,,G,s,R,i'),
#  Node("/['DIRECTORalias0.NATIONALITY']"),
#  Node("/['CUSTOMERSalias0.COUNTRY']"),
#  Node('/PEOPLEalias0.NAME/X,,,S'),
#  Node("/['CARS_DATAalias0.WEIGHT']"),
#  Node("/['HOSTalias0.NATIONALITY']"),
#  Node("/['BUSINESSalias0.CITY']"),
#  Node("/['STUDENTalias0.AGE']"),
#  Node("/['GAMEalias0.DATE', 'GAMEalias0.ID', 'GAMEalias0.SCORE']"),
#  Node("/['COURSE_OFFERINGalias0.FRIDAY', 'COURSE_OFFERINGalias0.MONDAY', 'COURSE_OFFERINGalias0.SATURDAY', 'COURSE_OFFERINGalias0.SUNDAY', 'COURSE_OFFERINGalias0.THURSDAY', 'COURSE_OFFERINGalias0.TUESDAY', 'COURSE_OFFERINGalias0.WEDNESDAY', 'SEMESTERalias0.SEMESTER', 'SEMESTERalias0.YEAR']"),
#  Node("/['INJURY_ACCIDENTalias0.NUMBER_OF_MATCHES', 'INJURY_ACCIDENTalias0.PLAYER', 'INJURY_ACCIDENTalias0.SOURCE']"),
#  Node("/['SHIPalias0.NATIONALITY']"),
#  Node("/['STATIONalias0.CITY']"),
#  Node('/DERIVED_TABLEalias0.UNIT_OF_MEASURE/Y,P,,,G,C'),
#  Node("/['BOOKINGSalias0.STATUS_CODE']"),
#  Node('/BUDGET_TYPE_DESCRIPTION/'),
#  Node('/COURSEalias0.NUMBER/A/,,D,P,T/0,I,a,S,O,.,l,A,N,E,U,s,R,i,C,M'),
#  Node('//0,W,E,S,.,N,D,T,_,H,K,a,O,P,l,A,,,s,R,i,C,M'),
#  Node("/['STATIONalias0.LOCATION']"),
#  Node('/PARTSalias0.PART_NAME/I,,,D'),
#  Node("/['AIRLINESalias0.NAME']"),
#  Node("/['VOTESalias0.PHONE_NUMBER', 'VOTESalias0.STATE', 'VOTESalias0.VOTE_ID']"),
#  Node('/BRANCHalias0.NAME/'),
#  Node("/['RACESalias0.NAME']"),
#  Node("/['BASKETBALL_MATCHalias0.TEAM_NAME']"),
#  Node("/['FOOD_SERVICEalias0.COMPARTMENT', 'FOOD_SERVICEalias0.MEAL_CODE', 'FOOD_SERVICEalias0.MEAL_DESCRIPTION', 'FOOD_SERVICEalias0.MEAL_NUMBER']"),
#  Node('//0,S,E,.,Z,B,D,_,I,a,O,l,,,G,s,R,i,C'),
#  Node("/['EMPLOYEEalias0.CITY']"),
#  Node("/['PARTSalias0.PART_NAME']"),
#  Node("/['PATIENTalias0.NAME']"),
#  Node("/['MANUFACTURERalias0.NAME']"),
#  Node('/PARTICIPANTSalias0.PARTICIPANT_TYPE_CODE/'),
#  Node("/['INVOICESalias0.BILLING_COUNTRY']"),
#  Node("/['COUNTRYalias0.COUNTRY_NAME']"),
#  Node('/MOVIEalias0.DIRECTOR/L'),
#  Node("/['CATALOG_PUBLISHER']"),
#  Node('/COUNTRIESalias0.COUNTRYNAME/D'),
#  Node("/['RESEARCH_STAFFalias0.STAFF_DETAILS']"),
#  Node("/['TRANSACTIONSalias0.INVESTOR_ID']"),
#  Node('/TOURIST_ATTRACTIONSalias0.NAME/D'),
#  Node('/AIRLINESalias0.COUNTRY/B,V,,'),
#  Node("/['ACTORalias0.BIRTH_CITY']"),
#  Node("/['FESTIVAL_DETAILalias0.CHAIR_NAME']"),
#  Node("/['TEACHERalias0.NAME']"),
#  Node('//0,E,S,.,N,D,T,_,L,I,a,O,P,l,A,,,U,s,R,i,C,M'),
#  Node("/['BRANCHalias0.OPEN_YEAR']"),
#  Node('/PRODUCTSalias0.PRODUCT_PRICE/A,,,M,N'),
#  Node("/['INSTRUCTORalias0.DEPT_NAME']"),
#  Node("/['CITYalias0.CITY_NAME']"),
#  Node("/['DEVICEalias0.SOFTWARE_PLATFORM']"),
#  Node('/CUSTOMERalias0.FIRST_NAME/L/I,,,D'),
#  Node("/['SECTIONalias0.YEAR']"),
#  Node("/['DEPARTMENTSalias0.DEPARTMENT_NAME', 'EMPLOYEESalias0.FIRST_NAME', 'EMPLOYEESalias0.LAST_NAME', 'LOCATIONSalias0.CITY', 'LOCATIONSalias0.STATE_PROVINCE']"),
#  Node("/['JOURNALalias0.HOMEPAGE']"),
#  Node('/PHYSICIANalias0.NAME/,,O,T'),
#  Node('/PNAME/,,S,H'),
#  Node('/CHURCHalias0.OPEN_DATE/M'),
#  Node("/['RIVERalias0.RIVER_NAME']"),
#  Node('/TOURIST_ATTRACTIONSalias0.NAME/P,,,H,G'),
#  Node('//0,E,S,.,N,F,T,_,L,I,a,O,P,l,A,,,s,R,i,M'),
#  Node('/CUSTOMERSalias0.CUSTOMER_NAME/L,H,V,I,,,F,D'),
#  Node("/['MUSIC_FESTIVALalias0.RESULT']"),
#  Node("/['PEOPLEalias0.WEIGHT']"),
#  Node("/['DERIVED_TABLEalias1.NAME']"),
#  Node("/['WINEalias0.YEAR']"),
#  Node('//0,E,S,.,N,D,_,H,L,I,a,O,P,l,,,s,R,i,C,M'),
#  Node("/['DORM_AMENITYalias0.AMENITY_NAME']"),
#  Node("/['BODY_BUILDERalias0.CLEAN_JERK']"),
#  Node('/PEOPLEalias0.NAME/_,H,I,,,B,R,D,T'),
#  Node('/STUDENTalias0.FNAME/G'),
#  Node("/['PURCHASESalias0.PURCHASE_DETAILS']"),
#  Node('//0,E,S,.,N,T,_,H,L,I,a,O,P,l,A,,,U,s,R,i,C,M'),
#  Node("/['EMPLOYEEalias0.NAME']"),
#  Node("/['INVOICESalias0.INVOICE_DATE', 'INVOICESalias0.ORDER_ID', 'ORDERSalias0.ORDER_DETAILS']"),
#  Node('/CHIP_MODELalias0.MODEL_NAME/B,R,,'),
#  Node("/['GOVERNMENTFORM']"),
#  Node("/['TRACKalias0.YEAR_OPENED']"),
#  Node('/BOOKalias0.TITLE/,,S,U'),
#  Node('/PAPERKEYPHRASEalias0.KEYPHRASEID/'),
#  Node("/['INVOICESalias0.BILLING_STATE']"),
#  Node('/STAFFalias0.STAFF_NAME/L,I,J,O,P,D,,,G,B,R,C'),
#  Node('/TRANSCRIPTSalias0.TRANSCRIPT_DATE/O'),
#  Node("/['WRITESalias2.AUTHORID']"),
#  Node("/['CONSTRUCTORSalias0.NAME']"),
#  Node("/['DERIVED_TABLEalias0.SERVICE_TYPE_DESCRIPTION']"),
#  Node('//0,E,S,.,N,B,D,T,_,I,K,a,O,P,l,A,,,G,s,R,i,M'),
#  Node('/CUSTOMERSalias0.CUSTOMER_NAME/P,,,H'),
#  Node("/['ARTWORKalias0.TYPE']"),
#  Node('/TRANSACTIONSalias0.DATE_OF_TRANSACTION/L'),
#  Node("/['FLIGHTalias0.PILOT']"),
#  Node("/['POKER_PLAYERalias0.EARNINGS']"),
#  Node('/PEOPLEalias0.FIRST_NAME/'),
#  Node('//0,W,E,.,N,T,H,a,O,A,l,,,G,s,R,i,C,M'),
#  Node('/COMPANYalias0.COMPANY/R,,,K/_,L,V,E,U,T'),
#  Node('/FLIGHTalias0.ORIGIN/S,E,A,,,D/F,N,O,L'),
#  Node("/['PAYMENTSalias0.AMOUNT_PAYMENT', 'PAYMENTSalias0.DATE_PAYMENT_MADE', 'PAYMENTSalias0.PAYMENT_ID']"),
#  Node('/AIRPORTNAME/,,C,D'),
#  Node("/['GENREalias0.GENRE']"),
#  Node("/['EMPLOYEESalias0.CITY']"),
#  Node('//0,E,S,.,N,F,D,_,L,I,K,a,l,A,,,U,s,R,i,C,M'),
#  Node("/['ORGANISATIONSalias0.ORGANISATION_DETAILS']"),
#  Node('/WINEalias0.NAME/S,O,,,R,C'),
#  Node('/TRACKalias0.NAME/I,,,O,L/_,Y,E,P,D'),
#  Node('/ROOMSalias0.ROOMNAME/V,,,I,T'),
#  Node("/['PARTYalias0.GOVERNOR']"),
#  Node("/['WRESTLERalias0.REIGN']"),
#  Node("/['RACEalias0.DATE', 'RACEalias0.NAME', 'TRACKalias0.NAME']"),
#  Node("/['ACCOUNTSalias0.ACCOUNT_ID', 'ACCOUNTSalias0.ACCOUNT_NAME', 'ACCOUNTSalias0.DATE_ACCOUNT_OPENED', 'ACCOUNTSalias0.OTHER_ACCOUNT_DETAILS']"),
#  Node("/['CUSTOMERSalias0.DATE_OF_BIRTH']"),
#  Node("/['TEMPLATE_TYPE_DESCRIPTION']"),
#  Node('/HIGHLOWalias0.STATE_NAME/P'),
#  Node('/EMPLOYEEalias0.EMP_FNAME/'),
#  Node('/DOCUMENT_LOCATIONSalias0.LOCATION_CODE/B,R,,,V'),
#  Node('/STUDENTSalias0.LOGIN_NAME/R,,,C'),
#  Node("/['VEHICLESalias0.VEHICLE_ID']"),
#  Node("/['FESTIVAL_DETAILalias0.NUM_OF_AUDIENCE']"),
#  Node("/['PLAYERSalias0.FIRST_NAME']"),
#  Node("/['PLAYERalias0.PLAYER_NAME']"),
#  Node("/['RESTRICTIONalias0.RESTRICTION_CODE']"),
#  Node("/['LOCATIONSalias0.COUNTRY_ID']"),
#  Node('/COURSEalias0.NAME/I,P,,,D,T'),
#  ...]
